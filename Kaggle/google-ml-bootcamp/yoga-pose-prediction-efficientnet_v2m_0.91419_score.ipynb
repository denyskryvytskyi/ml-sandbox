# %% [markdown]
# # Table of Contents

# %% [markdown]
# * [Import libs](#libs)
# * [Data Overview](#overview)
#     * [Data Loading](#data-loading)
#     * [Classes Distribution](#classses-distribution)
#     * [Show Images](#show-images)
# * [Preprocessing](#preprocessing)
#     * [Remove background](#remove-bg)
#     * [Train-val split](#train-val-split)
#     * [Apply preprocessing](#apply-preprocessing)
#     * [Generate Datasets](#gen=datasets)
# * [Model Training](#model)
#     * [Custom model](#custom-model)
#     * [Transfer learning](#transfer-learning)
#     * [Fine-tune model](#fine-tune)
# * [Test data](#test-data)
#      * [Preprocessing](#test-preprocessing)
#      * [Inference](#inference)

# %% [markdown]
# <a id='libs'></a>
# # Import libs

# %%
#!pip install rembg|

# %%
import shutil

from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from rembg import remove


import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Input, Activation, GlobalAveragePooling2D, Average
from tensorflow.keras.layers import Resizing, Rescaling, CenterCrop
from tensorflow.keras.layers import RandomCrop, RandomFlip, RandomTranslation, RandomRotation, RandomZoom, RandomContrast, RandomBrightness
from tensorflow.keras.preprocessing.image import ImageDataGenerator, smart_resize
from tensorflow.keras.utils import to_categorical, load_img, img_to_array, image_dataset_from_directory
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, AdamW, RMSprop, SGD
from tensorflow.keras.applications import DenseNet121, DenseNet169, DenseNet201, MobileNetV2, EfficientNetV2M
import tensorflow.keras.applications as applications
from tensorflow.keras.applications.efficientnet import EfficientNetB0, EfficientNetB2, EfficientNetB7
from tensorflow.keras import backend as K

from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
    # for filename in filenames:
        # print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# /kaggle/input
# /kaggle/input/ukraine-ml-bootcamp-2023
# /kaggle/input/ukraine-ml-bootcamp-2023/images
# /kaggle/input/ukraine-ml-bootcamp-2023/images/train_images
# /kaggle/input/ukraine-ml-bootcamp-2023/images/test_images

# %% [markdown]
# <a id='overview'></a>
# # Data overview

# %% [markdown]
# <a id='data-loading'></a>
# ## Data loading

# %%
SUBMISSION_DATA_FILE_PATH = "/kaggle/input/ukraine-ml-bootcamp-2023/sample_submission.csv"
TRAIN_DATA_FILE_PATH = "/kaggle/input/ukraine-ml-bootcamp-2023/train.csv"

TRAIN_IMAGES_SRC_PATH = "/kaggle/input/ukraine-ml-bootcamp-2023/images/train_images/"
TEST_IMAGES_SRC_PATH = "/kaggle/input/ukraine-ml-bootcamp-2023/images/test_images/"

PREPROCESSED_TRAIN_IMAGES_SRC_PATH= "/kaggle/working/preprocessed_train_images/"
PREPROCESSED_VAL_IMAGES_SRC_PATH= "/kaggle/working/preprocessed_val_images/"

preprocessed_train_images_dir = "preprocessed_train_images"
if not os.path.exists(preprocessed_train_images_dir):
    os.mkdir(preprocessed_train_images_dir)
    
preprocessed_val_images_dir = "preprocessed_val_images"
if not os.path.exists(preprocessed_val_images_dir):
    os.mkdir(preprocessed_val_images_dir)

# %%
df = pd.read_csv(TRAIN_DATA_FILE_PATH)
df.head()
# Out:
#                                image_id  class_6
# 0  1daf45401342ac321c0aa5668f51d004.jpg        5
# 1  7e15c14f0b25766d0b7378f1d5328e99.jpg        4
# 2  1dc97053cf67cb8e51c983abb0021083.jpg        4
# 3  0ceaf686d3b9c1db537fed12b568670d.jpg        1
# 4  73adbf71f0adcf89c94339f6a6a92b61.jpg        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2360 entries, 0 to 2359
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image_id  2360 non-null   object
#  1   class_6   2360 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 37.0+ KB

# %% [markdown]
# <a id='classses-distribution'></a>
# ## Classes Distribution

# %%
df['class_6'].value_counts().plot(kind='bar', title='Classes distribution')
# Out:
# <Axes: title={'center': 'Classes distribution'}>

# %% [markdown]
# <a id='show-images'></a>
# ## Show Images

# %%
rows = 4
cols = 4
imgs_amount_to_show = rows * cols

fig = plt.gcf()
fig.set_size_inches(rows * 4, rows * 4)

for i in range(imgs_amount_to_show):
    img = load_img(TRAIN_IMAGES_SRC_PATH + df['image_id'][i])
    
    sp = plt.subplot(rows, cols, i + 1)
    sp.axis('Off')
    plt.title(f"Class #{df['class_6'][i]}")
    plt.imshow(img)
    
plt.show()

# %% [markdown]
# <a id='preprocessing'></a>
# # Preprocessing

# %%
BATCH_SIZE = 16
IMG_SIZE = 224
VALIDATION_SPLIT = 0.1

# %% [markdown]
# <a id='train-val-split'></a>
# ## Train-val split

# %%
df['class_6'] = df['class_6'].astype(str)
train_df, val_df = train_test_split(df, test_size=VALIDATION_SPLIT, stratify=df['class_6'])
print(f'Train data shape: {len(train_df)}')
print(f'Validation data shape: {len(val_df)}')
# Out:
# Train data shape: 2124
# Validation data shape: 236

# %% [markdown]
# <a id='remove-bg'></a>
# ## Remove background

# %%
def rembg(img_path):
    # Loading the image
    img = Image.open(img_path)

    # Removing the background from the given Image
    output = remove(img)

    return output

# %%
def test_rembg():
    for i in range(imgs_amount_to_show):
        img = rembg(TRAIN_IMAGES_SRC_PATH + df['image_id'][i])

        sp = plt.subplot(rows, cols, i + 1)
        sp.axis('Off')
        plt.title(f"Class #{df['class_6'][i]}")
        plt.imshow(img)

    plt.show()

# %%
#test_rembg()

# %% [markdown]
# <a id='apply-preprocessing'></a>
# ## Apply preprocessing

# %%
# The score is higher (with pretrained model) without erasing the background, so I commented on the logic behind that. You can uncomment it for experimentation.
# This function sorts images by classes into appropriate folders for now.
def preprocess_img(src_dir_path, res_dir_path, img_filename, class_name):
    src_full_path = os.path.join(src_dir_path, img_filename)
    #img = rembg(src_full_path)
    #img = img.convert("RGB")
    
    save_dir = os.path.join(res_dir_path, str(class_name))
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
           
    save_full_path = os.path.join(save_dir, img_filename)
    #img.save(save_full_path, format="png")
    shutil.copy(src_full_path, save_full_path)

# %%
for index, row in train_df.iterrows():
    preprocess_img(TRAIN_IMAGES_SRC_PATH, PREPROCESSED_TRAIN_IMAGES_SRC_PATH, row.image_id, row.class_6)
    
for index, row in val_df.iterrows():
    preprocess_img(TRAIN_IMAGES_SRC_PATH, PREPROCESSED_VAL_IMAGES_SRC_PATH, row.image_id, row.class_6)

# %% [markdown]
# <a id='gen=datasets'></a>
# ## Generate Datasets

# %%
train_ds = image_dataset_from_directory(
    directory=PREPROCESSED_TRAIN_IMAGES_SRC_PATH,
    labels="inferred",
    label_mode="categorical",
    batch_size=BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    interpolation="bilinear"
)

val_ds = image_dataset_from_directory(
    directory=PREPROCESSED_VAL_IMAGES_SRC_PATH,
    labels="inferred",
    label_mode="categorical",
    batch_size=BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    interpolation="bilinear"
)
# Out:
# Found 2124 files belonging to 6 classes.
# Found 236 files belonging to 6 classes.

# %%
class_names = train_ds.class_names

for images, labels in train_ds.take(1):
    for i in range(len(images)):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# <a id='model'></a>
#
# # Model training

# %%
def plot_model_history(history):
    # Plot the chart for accuracy and loss on both training and validation
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    f1_score = history.history['micro_f1_score']
    val_f1_score = history.history['val_micro_f1_score']

    epochs = range(len(acc))

    plt.plot(epochs, acc, 'r', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, 'r', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Training and validation loss')
    plt.legend()
    plt.figure()
    
    plt.plot(epochs, f1_score, 'r', label='Training F1-score')
    plt.plot(epochs, val_f1_score, 'b', label='Validation F1-score')
    plt.title('Training and validation F1-score')
    plt.legend()

    plt.show()

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=1e-6)
#reduce_densenet_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-3)
early_stopping = EarlyStopping('val_loss', patience=15, restore_best_weights=True)

# %%
def micro_f1_score(y_true, y_pred):
    # Convert predictions to one-hot vectors
    y_pred = K.one_hot(K.argmax(y_pred), num_classes=6)

    # Calculate true positives, false positives, and false negatives over all classes
    tp = K.sum(K.cast(y_true*y_pred, 'float'), axis=0)
    fp = K.sum(K.cast((1-y_true)*y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true*(1-y_pred), 'float'), axis=0)

    # Micro-average precision and recall
    micro_precision = K.sum(tp) / (K.sum(tp + fp) + K.epsilon())
    micro_recall = K.sum(tp) / (K.sum(tp + fn) + K.epsilon())

    # Calculate micro-averaged F1-score
    micro_f1 = 2 * micro_precision * micro_recall / (micro_precision + micro_recall + K.epsilon())

    return micro_f1

# %% [markdown]
# <a id='custom-model'></a>
# ## Custom Model

# %%
def build_model():
    model=Sequential([
        Input(shape=(IMG_SIZE, IMG_SIZE, 3), name='inputLayer'),
        Rescaling(1./255),
        RandomFlip("horizontal"),
        RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1)),
        RandomZoom(0.2),

        Conv2D(filters=32, kernel_size=5, activation="relu"),
        BatchNormalization(),
        MaxPooling2D(),
        
        Conv2D(filters=64, kernel_size=5, activation="relu" ),
        BatchNormalization(),
        MaxPooling2D(),
        
        Conv2D(filters=128, kernel_size=5, activation="relu" ),
        BatchNormalization(),
        MaxPooling2D(),
        
        Conv2D(filters=256, kernel_size=3, activation="relu" ),
        BatchNormalization(),
        MaxPooling2D(),
        
        Conv2D(filters=256, kernel_size=3, activation="relu" ),
        BatchNormalization(),
        MaxPooling2D(),
        
        Flatten(),
        Dense(units=128, activation="relu"),
        Dense(units=6, activation='softmax')
    ])

    model.compile(optimizer=Adam(learning_rate=1e-3),
                  loss = 'categorical_crossentropy',
                  metrics=["accuracy", micro_f1_score])
    return model

# %%
#custom_model = build_model()
#custom_model.summary()

# %%
#history_custom_model = custom_model.fit(train_ds, validation_data = (val_ds), epochs=100, callbacks=[reduce_lr, early_stopping])

# %%
#plot_model_history(history_custom_model)

# %% [markdown]
# <a id='transfer-learning'></a>
# # Transfer Learning

# %%
def unfreeze_model(model, optimizer):
    # We unfreeze all layers, leaving the BatchNorm layers frozen to preserve model knowledge.
    for layer in model.layers:
        if not isinstance(layer, BatchNormalization):
            layer.trainable = True

    model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy", micro_f1_score])

# %% [markdown]
# ## EfficientNet

# %%
def build_efficientnet_model():
    base_model = EfficientNetV2M(include_top=False, weights="imagenet", input_shape=(IMG_SIZE, IMG_SIZE, 3))

    # Freeze the pretrained weights
    base_model.trainable = False

    # Augmantation sequence
    intput_layer = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    augmantation = Sequential([
        #Rescaling(1/255),
        RandomFlip("horizontal"),
        RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1)),
        RandomZoom(0.2)
    ])
    x = augmantation(intput_layer)
    
    # pretrain output
    pretrain_out = base_model(x, training = False)
    
    # Rebuild top
    x = GlobalAveragePooling2D()(pretrain_out)
    x = BatchNormalization()(x)
    x = Dense(64, activation='relu', kernel_regularizer=regularizers.l2(1e-3))(x)
    
    # Add a dropout rate 
    x = Dropout(0.2)(x)
    
    # Output layer
    outputs = Dense(6, activation="softmax")(x)

    # Compile
    model = tf.keras.Model(inputs=intput_layer, outputs=outputs, name="EfficientNet")
    model.compile(optimizer=SGD(learning_rate=1e-2), loss="categorical_crossentropy", metrics=["accuracy", micro_f1_score])
    
    return model

# %%
model_efficient = build_efficientnet_model()
model_efficient.summary()
# Out:
# Model: "EfficientNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential_3 (Sequential)   (None, 224, 224, 3)       0
#
#  efficientnetv2-m (Functiona  (None, 7, 7, 1280)       53150388
#  l)
#
#  global_average_pooling2d_3   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  batch_normalization_3 (Batc  (None, 1280)             5120
#  hNormalization)
#
#  dense_6 (Dense)             (None, 64)                81984
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 53,237,882
# Trainable params: 84,934
# Non-trainable params: 53,152,948
# _________________________________________________________________

# %%
history_efficient = model_efficient.fit(train_ds, validation_data = val_ds, epochs=100, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 133/133 [==============================] - 41s 152ms/step - loss: 1.8634 - accuracy: 0.3597 - micro_f1_score: 0.3600 - val_loss: 1.5830 - val_accuracy: 0.4492 - val_micro_f1_score: 0.4500
# Epoch 2/100
# 133/133 [==============================] - 17s 122ms/step - loss: 1.4290 - accuracy: 0.5071 - micro_f1_score: 0.5067 - val_loss: 1.3741 - val_accuracy: 0.5042 - val_micro_f1_score: 0.5042
# Epoch 3/100
# 133/133 [==============================] - 16s 114ms/step - loss: 1.2655 - accuracy: 0.5725 - micro_f1_score: 0.5728 - val_loss: 1.2879 - val_accuracy: 0.5254 - val_micro_f1_score: 0.5306
# Epoch 4/100
# 133/133 [==============================] - 16s 119ms/step - loss: 1.1675 - accuracy: 0.6153 - micro_f1_score: 0.6158 - val_loss: 1.2455 - val_accuracy: 0.5466 - val_micro_f1_score: 0.5458
# Epoch 5/100
# 133/133 [==============================] - 16s 113ms/step - loss: 1.1097 - accuracy: 0.6384 - micro_f1_score: 0.6382 - val_loss: 1.2217 - val_accuracy: 0.5720 - val_micro_f1_score: 0.5736
# Epoch 6/100
# 133/133 [==============================] - 17s 121ms/step - loss: 1.0711 - accuracy: 0.6436 - micro_f1_score: 0.6433 - val_loss: 1.1689 - val_accuracy: 0.5805 - val_micro_f1_score: 0.5806
# Epoch 7/100
# 133/133 [==============================] - 15s 111ms/step - loss: 1.0184 - accuracy: 0.6718 - micro_f1_score: 0.6720 - val_loss: 1.1760 - val_accuracy: 0.6059 - val_micro_f1_score: 0.6069
# Epoch 8/100
# 133/133 [==============================] - 16s 120ms/step - loss: 0.9765 - accuracy: 0.6747 - micro_f1_score: 0.6748 - val_loss: 1.1687 - val_accuracy: 0.6059 - val_micro_f1_score: 0.6069
# Epoch 9/100
# 133/133 [==============================] - 16s 114ms/step - loss: 0.9208 - accuracy: 0.6987 - micro_f1_score: 0.6988 - val_loss: 1.1604 - val_accuracy: 0.6102 - val_micro_f1_score: 0.6125
# Epoch 10/100
# 133/133 [==============================] - 17s 121ms/step - loss: 0.9436 - accuracy: 0.6982 - micro_f1_score: 0.6982 - val_loss: 1.1006 - val_accuracy: 0.6186 - val_micro_f1_score: 0.6222
# Epoch 11/100
# 133/133 [==============================] - 15s 111ms/step - loss: 0
100
# 133/133 [==============================] - 16s 115ms/step - loss: 0.4550 - accuracy: 0.8809 - micro_f1_score: 0.8805 - val_loss: 1.1388 - val_accuracy: 0.6780 - val_micro_f1_score: 0.6750
# Epoch 59/100
# 133/133 [==============================] - 17s 123ms/step - loss: 0.4283 - accuracy: 0.8898 - micro_f1_score: 0.8896 - val_loss: 1.1768 - val_accuracy: 0.6695 - val_micro_f1_score: 0.6681
# Epoch 60/100
# 133/133 [==============================] - 15s 113ms/step - loss: 0.4690 - accuracy: 0.8781 - micro_f1_score: 0.8781 - val_loss: 1.1242 - val_accuracy: 0.6822 - val_micro_f1_score: 0.6806
# Epoch 61/100
# 133/133 [==============================] - 17s 121ms/step - loss: 0.4747 - accuracy: 0.8719 - micro_f1_score: 0.8719 - val_loss: 1.1470 - val_accuracy: 0.6780 - val_micro_f1_score: 0.6764
# Epoch 62/100
# 133/133 [==============================] - 17s 122ms/step - loss: 0.4506 - accuracy: 0.8743 - micro_f1_score: 0.8742 - val_loss: 1.1291 - val_accuracy: 0.6695 - val_micro_f1_score: 0.6667
# Epoch 63/100
# 133/133 [==============================] - 16s 119ms/step - loss: 0.4737 - accuracy: 0.8705 - micro_f1_score: 0.8705 - val_loss: 1.1464 - val_accuracy: 0.6737 - val_micro_f1_score: 0.6750

# %%
plot_model_history(history_efficient)

# %% [markdown]
# <a id='fine-tune'></a>
# ### Fine-tune model

# %%
optimizer_efficient_ft = Adam(learning_rate=1e-4)
unfreeze_model(model_efficient, optimizer_efficient_ft)

total_params = model_efficient.count_params()
num_trainable_params = sum([w.shape.num_elements() for w in model_efficient.trainable_weights])

print(f"There are {total_params:,} total parameters in this model.")
print(f"There are {num_trainable_params:,} trainable parameters in this model.")
# Out:
# There are 53,237,882 total parameters in this model.
# There are 52,943,290 trainable parameters in this model.

# %%
history_efficient_ft = model_efficient.fit(train_ds, validation_data = val_ds, epochs=100, callbacks=[reduce_lr, early_stopping])
# Out:
# Epoch 1/100
# 133/133 [==============================] - 190s 369ms/step - loss: 1.0698 - accuracy: 0.7062 - micro_f1_score: 0.7065 - val_loss: 1.4376 - val_accuracy: 0.6907 - val_micro_f1_score: 0.6931 - lr: 1.0000e-04
# Epoch 2/100
# 133/133 [==============================] - 43s 321ms/step - loss: 0.6171 - accuracy: 0.8338 - micro_f1_score: 0.8338 - val_loss: 0.9802 - val_accuracy: 0.7415 - val_micro_f1_score: 0.7458 - lr: 1.0000e-04
# Epoch 3/100
# 133/133 [==============================] - 44s 326ms/step - loss: 0.4449 - accuracy: 0.8912 - micro_f1_score: 0.8910 - val_loss: 0.6893 - val_accuracy: 0.8051 - val_micro_f1_score: 0.8083 - lr: 1.0000e-04
# Epoch 4/100
# 133/133 [==============================] - 43s 318ms/step - loss: 0.3336 - accuracy: 0.9350 - micro_f1_score: 0.9352 - val_loss: 0.9543 - val_accuracy: 0.7966 - val_micro_f1_score: 0.7958 - lr: 1.0000e-04
# Epoch 5/100
# 133/133 [==============================] - 43s 323ms/step - loss: 0.2484 - accuracy: 0.9572 - micro_f1_score: 0.9572 - val_loss: 0.5605 - val_accuracy: 0.8602 - val_micro_f1_score: 0.8583 - lr: 1.0000e-04
# Epoch 6/100
# 133/133 [==============================] - 44s 322ms/step - loss: 0.2538 - accuracy: 0.9557 - micro_f1_score: 0.9558 - val_loss: 0.7142 - val_accuracy: 0.8432 - val_micro_f1_score: 0.8458 - lr: 1.0000e-04
# Epoch 7/100
# 133/133 [==============================] - 43s 321ms/step - loss: 0
# Epoch 48/100
# 133/133 [==============================] - 43s 323ms/step - loss: 0.0980 - accuracy: 0.9995 - micro_f1_score: 0.9995 - val_loss: 0.3708 - val_accuracy: 0.9407 - val_micro_f1_score: 0.9417 - lr: 4.0000e-06
# Epoch 49/100
# 133/133 [==============================] - 43s 322ms/step - loss: 0.1017 - accuracy: 0.9991 - micro_f1_score: 0.9991 - val_loss: 0.3835 - val_accuracy: 0.9449 - val_micro_f1_score: 0.9458 - lr: 4.0000e-06
# Epoch 50/100
# 133/133 [==============================] - 44s 327ms/step - loss: 0.0983 - accuracy: 0.9991 - micro_f1_score: 0.9991 - val_loss: 0.3783 - val_accuracy: 0.9449 - val_micro_f1_score: 0.9458 - lr: 4.0000e-06
# Epoch 51/100
# 133/133 [==============================] - 44s 326ms/step - loss: 0.0968 - accuracy: 1.0000 - micro_f1_score: 1.0000 - val_loss: 0.3736 - val_accuracy: 0.9407 - val_micro_f1_score: 0.9403 - lr: 4.0000e-06

# %%
plot_model_history(history_efficient_ft)

# %% [markdown]
# ## DenseNet201

# %%
def build_densenet_model():
    base_model = DenseNet201(include_top=False, weights="imagenet", input_shape=(IMG_SIZE, IMG_SIZE, 3))

    # Freeze the pretrained weights
    base_model.trainable = False

    # Augmantation sequence
    intput_layer = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    augmantation = Sequential([
        Rescaling(1/255),
        RandomFlip("horizontal"),
        RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1)),
        RandomZoom(0.2)
    ])
    x = augmantation(intput_layer)
    
    # pretrain output
    pretrain_out = base_model(x, training = False)
    
    # Rebuild top
    x = GlobalAveragePooling2D()(pretrain_out)
    x = BatchNormalization()(x)
    x = Dense(64, activation='relu', kernel_regularizer=regularizers.l2(1e-3))(x)
    
    # Add a dropout rate 
    x = Dropout(0.2)(x)
    
    # Output layer
    outputs = Dense(6, activation="softmax")(x)

    # Compile
    model = tf.keras.Model(inputs=intput_layer, outputs=outputs, name="DenseNet201")
    model.compile(optimizer=SGD(learning_rate=1e-2), loss="categorical_crossentropy", metrics=["accuracy", micro_f1_score])
    
    return model

# %%
model_densenet = build_densenet_model()
model_densenet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Model: "DenseNet201"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential_4 (Sequential)   (None, 224, 224, 3)       0
#
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d_4   (None, 1920)             0
#  (GlobalAveragePooling2D)
#
#  batch_normalization_4 (Batc  (None, 1920)             7680
#  hNormalization)
#
#  dense_8 (Dense)             (None, 64)                122944
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 18,452,998
# Trainable params: 127,174
# Non-trainable params: 18,325,824
# _________________________________________________________________

# %%
history = model_densenet.fit(train_ds, validation_data = val_ds, epochs=100, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 133/133 [==============================] - 78s 160ms/step - loss: 1.7206 - accuracy: 0.3743 - micro_f1_score: 0.3747 - val_loss: 1.4648 - val_accuracy: 0.5169 - val_micro_f1_score: 0.5153
# Epoch 2/100
# 133/133 [==============================] - 16s 116ms/step - loss: 1.3017 - accuracy: 0.5678 - micro_f1_score: 0.5680 - val_loss: 1.2954 - val_accuracy: 0.6059 - val_micro_f1_score: 0.6056
# Epoch 3/100
# 133/133 [==============================] - 15s 109ms/step - loss: 1.1472 - accuracy: 0.6290 - micro_f1_score: 0.6289 - val_loss: 1.2030 - val_accuracy: 0.5932 - val_micro_f1_score: 0.5917
100
# 133/133 [==============================] - 15s 112ms/step - loss: 0.5915 - accuracy: 0.8300 - micro_f1_score: 0.8302 - val_loss: 0.9934 - val_accuracy: 0.6822 - val_micro_f1_score: 0.6819
# Epoch 21/100
# 133/133 [==============================] - 15s 107ms/step - loss: 0.5663 - accuracy: 0.8413 - micro_f1_score: 0.8412 - val_loss: 0.9844 - val_accuracy: 0.6822 - val_micro_f1_score: 0.6806
# Epoch 22/100
# 133/133 [==============================] - 15s 112ms/step - loss: 0.5623 - accuracy: 0.8498 - micro_f1_score: 0.8496 - val_loss: 0.9894 - val_accuracy: 0.6992 - val_micro_f1_score: 0.6986
# Epoch 23/100
# 133/133 [==============================] - 15s 107ms/step - loss: 0.5227 - accuracy: 0.8597 - micro_f1_score: 0.8600 - val_loss: 1.0063 - val_accuracy: 0.6992 - val_micro_f1_score: 0.6986
# Epoch 24/100
# 133/133 [==============================] - 15s 112ms/step - loss: 0.5414 - accuracy: 0.8550 - micro_f1_score: 0.8549 - val_loss: 1.0180 - val_accuracy: 0.6949 - val_micro_f1_score: 0.6917
# Epoch 25/100
# 133/133 [==============================] - 15s 108ms/step - loss: 0.5316 - accuracy: 0.8588 - micro_f1_score: 0.8589 - val_loss: 1.0097 - val_accuracy: 0.7034 - val_micro_f1_score: 0.7014
# Epoch 26/100
# 133/133 [==============================] - 15s 112ms/step - loss: 0.4991 - accuracy: 0.8715 - micro_f1_score: 0.8711 - val_loss: 0.9898 - val_accuracy: 0.7076 - val_micro_f1_score: 0.7083
# Epoch 27/100
# 133/133 [==============================] - 15s 107ms/step - loss: 0.5008 - accuracy: 0.8729 - micro_f1_score: 0.8730 - val_loss: 1.0138 - val_accuracy: 0.6907 - val_micro_f1_score: 0.6917
# Epoch 28/100
# 133/133 [==============================] - 15s 112ms/step - loss: 0.4739 - accuracy: 0.8856 - micro_f1_score: 0.8858 - val_loss: 1.0065 - val_accuracy: 0.6907 - val_micro_f1_score: 0.6903
# Epoch 29/100
# 133/133 [==============================] - 15s 107ms/step - loss: 0.5092 - accuracy: 0.8639 - micro_f1_score: 0.8639 - val_loss: 0.9997 - val_accuracy: 0.6907 - val_micro_f1_score: 0.6903
# Epoch 30/100
# 133/133 [==============================] - 15s 113ms/step - loss: 0.4832 - accuracy: 0.8653 - micro_f1_score: 0.8654 - val_loss: 1.0058 - val_accuracy: 0.6949 - val_micro_f1_score: 0.6958
# Epoch 31/100
# 133/133 [==============================] - 15s 110ms/step - loss: 0.4937 - accuracy: 0.8691 - micro_f1_score: 0.8687 - val_loss: 1.0042 - val_accuracy: 0.6992 - val_micro_f1_score: 0.6972

# %%
plot_model_history(history)

# %% [markdown]
# <a id='fine-tune'></a>
# ### Fine-tune model

# %%
print(f'Model layers amount: {len(model_densenet.layers)}')
# Out:
# Model layers amount: 8

# %%
optimizer_densenet_ft = Adam(learning_rate=1e-4)
unfreeze_model(model_densenet, optimizer_densenet_ft)

total_params = model_densenet.count_params()
num_trainable_params = sum([w.shape.num_elements() for w in model_densenet.trainable_weights])

print(f"There are {total_params:,} total parameters in this model.")
print(f"There are {num_trainable_params:,} trainable parameters in this model.")
# Out:
# There are 18,452,998 total parameters in this model.
# There are 18,220,102 trainable parameters in this model.

# %%
early_stopping_unfreezed = EarlyStopping('val_loss', patience=10, restore_best_weights=True)

# %%
history_densenet_ft = model_densenet.fit(train_ds, validation_data = val_ds, epochs=100, callbacks=[reduce_lr, early_stopping])
# Out:
# Epoch 1/100
#
100
# 133/133 [==============================] - 33s 246ms/step - loss: 0.0705 - accuracy: 0.9976 - micro_f1_score: 0.9977 - val_loss: 0.3643 - val_accuracy: 0.9068 - val_micro_f1_score: 0.9069 - lr: 2.0000e-05
# Epoch 31/100
# 133/133 [==============================] - 33s 242ms/step - loss: 0.0730 - accuracy: 0.9967 - micro_f1_score: 0.9967 - val_loss: 0.3372 - val_accuracy: 0.9195 - val_micro_f1_score: 0.9194 - lr: 2.0000e-05
# Epoch 32/100
# 133/133 [==============================] - 33s 241ms/step - loss: 0.0735 - accuracy: 0.9967 - micro_f1_score: 0.9967 - val_loss: 0.3301 - val_accuracy: 0.9280 - val_micro_f1_score: 0.9292 - lr: 2.0000e-05
# Epoch 33/100
# 133/133 [==============================] - 33s 242ms/step - loss: 0.0712 - accuracy: 0.9958 - micro_f1_score: 0.9958 - val_loss: 0.3303 - val_accuracy: 0.9110 - val_micro_f1_score: 0.9111 - lr: 2.0000e-05
# Epoch 34/100
# 133/133 [==============================] - 33s 241ms/step - loss: 0.0674 - accuracy: 0.9972 - micro_f1_score: 0.9972 - val_loss: 0.3338 - val_accuracy: 0.9237 - val_micro_f1_score: 0.9250 - lr: 4.0000e-06
# Epoch 35/100
# 133/133 [==============================] - 33s 244ms/step - loss: 0.0653 - accuracy: 0.9976 - micro_f1_score: 0.9977 - val_loss: 0.3329 - val_accuracy: 0.9280 - val_micro_f1_score: 0.9292 - lr: 4.0000e-06
# Epoch 36/100
# 133/133 [==============================] - 33s 244ms/step - loss: 0.0676 - accuracy: 0.9981 - micro_f1_score: 0.9981 - val_loss: 0.3428 - val_accuracy: 0.9195 - val_micro_f1_score: 0.9208 - lr: 4.0000e-06
# Epoch 37/100
# 133/133 [==============================] - 33s 241ms/step - loss: 0.0638 - accuracy: 0.9995 - micro_f1_score: 0.9995 - val_loss: 0.3403 - val_accuracy: 0.9153 - val_micro_f1_score: 0.9167 - lr: 4.0000e-06
# Epoch 38/100
# 133/133 [==============================] - 33s 246ms/step - loss: 0.0705 - accuracy: 0.9962 - micro_f1_score: 0.9962 - val_loss: 0.3386 - val_accuracy: 0.9153 - val_micro_f1_score: 0.9153 - lr: 4.0000e-06

# %%
plot_model_history(history)

# %% [markdown]
# ## Mobilenet

# %%
def build_mobilenet_model():
    base_model = MobileNetV2(include_top=False, weights="imagenet", input_shape=(IMG_SIZE, IMG_SIZE, 3))

    # Freeze the pretrained weights
    base_model.trainable = False

    # Augmantation sequence
    intput_layer = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    augmantation = Sequential([
        #Rescaling(1/255),
        RandomFlip("horizontal"),
        RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1)),
        RandomZoom(0.2)
    ])
    x = augmantation(intput_layer)
    
    x = applications.mobilenet_v2.preprocess_input(x)
    
    # pretrain output
    pretrain_out = base_model(x, training = False)
    
    # Rebuild top
    x = GlobalAveragePooling2D()(pretrain_out)
    x = BatchNormalization()(x)
    x = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(1e-3))(x)
    
    # Add a dropout rate 
    x = Dropout(0.2)(x)
    
    # Output layer
    outputs = Dense(6, activation="softmax")(x)

    # Compile
    model = tf.keras.Model(inputs=intput_layer, outputs=outputs, name="MobileNetV2")
    model.compile(optimizer=SGD(learning_rate=1e-2), loss="categorical_crossentropy", metrics=["accuracy", micro_f1_score])
    
    return model

# %%
model_mobilenet = build_mobilenet_model()
total_params = model_mobilenet.count_params()
num_trainable_params = sum([w.shape.num_elements() for w in model_mobilenet.trainable_weights])

model_mobilenet.summary()
# Out:
# Model: "MobileNetV2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  sequential_6 (Sequential)   (None, 224, 224, 3)       0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_1 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_6   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  batch_normalization_6 (Batc  (None, 1280)             5120
#  hNormalization)
#
#  dense_15 (Dense)            (None, 128)               163968
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_16 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 2,427,846
# Trainable params: 167,302
# Non-trainable params: 2,260,544
# _________________________________________________________________

# %%
history_mobilenet = model_mobilenet.fit(train_ds, validation_data = val_ds, epochs=100, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 133/133 [==============================] - 17s 98ms/step - loss: 2.0441 - accuracy: 0.3498 - micro_f1_score: 0.3498 - val_loss: 1.6350 - val_accuracy: 0.4703 - val_micro_f1_score: 0.4694
# Epoch 2/100
# 133/133 [==============================] - 14s 99ms/step - loss: 1.5011 - accuracy: 0.5292 - micro_f1_score: 0.5290 - val_loss: 1.5385 - val_accuracy: 0.4915 - val_micro_f1_score: 0.4917
# Epoch 3/100
# 133/133 [==============================] - 12s 90ms/step - loss: 1.3286 - accuracy: 0.5989 - micro_f1_score: 0.5985 - val_loss: 1.4990 - val_accuracy: 0.5127 - val_micro_f1_score: 0.5083
# Epoch 4/100
# 133/133 [==============================] - 12s 90ms/step - loss: 1.2243 - accuracy: 0.6332 - micro_f1_score: 0.6331 - val_loss: 1.4719 - val_accuracy: 0.5297 - val_micro_f1_score: 0.5264
# Epoch 5/100
# 133/133 [==============================] - 13s 96ms/step - loss: 1.1609 - accuracy: 0.6577 - micro_f1_score: 0.6573 - val_loss: 1.4636 - val_accuracy: 0.5466 - val_micro_f1_score: 0.5458
# Epoch 6/100
# 133/133 [==============================] - 12s 90ms/step - loss: 1.0755 - accuracy: 0.6831 - micro_f1_score: 0.6828 - val_loss: 1.4518 - val_accuracy: 0.5551 - val_micro_f1_score: 0.5542
# Epoch 7/100
# 133/133 [==============================] - 14s 99ms/step - loss: 1.0392 - accuracy: 0.6935 - micro_f1_score: 0.6936 - val_loss: 1.4314 - val_accuracy: 0.5424 - val_micro_f1_score: 0.5444
# Epoch 8/100
# 133/133 [==============================] - 12s 90ms/step - loss: 0.9950 - accuracy: 0.7109 - micro_f1_score: 0.7110 - val_loss: 1.4135 - val_accuracy: 0.5551 - val_micro_f1_score: 0.5556
# Epoch 9/100
# 133/133 [==============================] - 12s 89ms/step - loss: 0.9618 - accuracy: 0.7189 - micro_f1_score: 0.7191 - val_loss: 1.4159 - val_accuracy: 0.5466 - val_micro_f1_score: 0.5431
# Epoch 10/100
# 133/133 [==============================] - 13s 95ms/step - loss: 0.9147 - accuracy: 0.7538 - micro_f1_score: 0.7541 - val_loss: 1.4169 - val_accuracy: 0.5890 - val_micro_f1_score: 0.5917
# Epoch 11/100
# 133/133 [==============================] - 12s 90ms/step - loss: 0.8930 - accuracy: 0.7467 - micro_f1_score: 0.7464 - val_loss: 1.4233 - val_accuracy: 0.5720 - val_micro_f1_score: 0.5708
# Epoch 12/100
# 133/133 [==============================] - 13s 91ms/step - loss: 0.8486 - accuracy: 0.7754 - micro_f1_score: 0.7752 - val_loss: 1.4296 - val_accuracy: 0.5932 - val_micro_f1_score: 0.5931
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 history_mobilenet = model_mobilenet.fit(train_ds, validation_data = val_ds, epochs=100, callbacks=[early_stopping])
#
# File /opt/conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
plot_model_history(history_mobilenet)

# %%
unfreeze_model(model_mobilenet)

total_params = model_mobilenet.count_params()
num_trainable_params = sum([w.shape.num_elements() for w in model_mobilenet.trainable_weights])

print(f"There are {total_params:,} total parameters in this model.")
print(f"There are {num_trainable_params:,} trainable parameters in this model.")
# Out:
# There are 2,427,846 total parameters in this model.
# There are 2,391,174 trainable parameters in this model.

# %%
history_mobilenet = model_mobilenet.fit(train_ds, validation_data = val_ds, epochs=100, callbacks=[reduce_lr, early_stopping])
# Out:
# Epoch 1/100
# 133/133 [==============================] - 47s 120ms/step - loss: 1.2427 - accuracy: 0.5556 - micro_f1_score: 0.5553 - val_loss: 2.1912 - val_accuracy: 0.4831 - val_micro_f1_score: 0.4847 - lr: 1.0000e-04
# Epoch 2/100
# 133/133 [==============================] - 15s 106ms/step - loss: 0.9793 - accuracy: 0.6460 - micro_f1_score: 0.6457 - val_loss: 1.5404 - val_accuracy: 0.5466 - val_micro_f1_score: 0.5444 - lr: 1.0000e-04
# Epoch 3/100
# 133/133 [==============================] - 15s 111ms/step - loss: 0.8986 - accuracy: 0.6883 - micro_f1_score: 0.6878 - val_loss: 1.9019 - val_accuracy: 0.5551 - val_micro_f1_score: 0.5569 - lr: 1.0000e-04
# Epoch 4/100
# 133/133 [==============================] - 14s 105ms/step - loss: 0.7495 - accuracy: 0.7326 - micro_f1_score: 0.7325 - val_loss: 0.8451 - val_accuracy: 0.7373 - val_micro_f1_score: 0.7403 - lr: 1.0000e-04
# Epoch 5/100
# 133/133 [==============================] - 15s 109ms/step - loss: 0.5886 - accuracy: 0.7990 - micro_f1_score: 0.7986 - val_loss: 0.9665 - val_accuracy: 0.6992 - val_micro_f1_score: 0.6986 - lr: 1.0000e-04
# Epoch 6/100
# 133/133 [==============================] - 15s 106ms/step - loss: 0.5604 - accuracy: 0.8093 - micro_f1_score: 0.8094 - val_loss: 1.0658 - val_accuracy: 0.7415 - val_micro_f1_score: 0.7417 - lr: 1.0000e-04
# Epoch 7/100
# 133/133 [==============================] - 14s 105ms/step - loss: 0.4943 - accuracy: 0.8305 - micro_f1_score: 0.8302 - val_loss: 0.8244 - val_accuracy: 0.7924 - val_micro_f1_score: 0.7903 - lr: 1.0000e-04
# Epoch 8/100
# 133/133 [==============================] - 15s 109ms/step - loss: 0.4439 - accuracy: 0.8498 - micro_f1_score: 0.8495 - val_loss: 0.7760 - val_accuracy: 0.7839 - val_micro_f1_score: 0.7833 - lr: 1.0000e-04
# Epoch 9/100
# 133/133 [==============================] - 15s 106ms/step - loss: 0.4228 - accuracy: 0.8621 - micro_f1_score: 0.8623 - val_loss: 1.2653 - val_accuracy: 0.7373 - val_micro_f1_score: 0.7361 - lr: 1.0000e-04
# Epoch 10/100
# 133/133 [==============================] - 16s 113ms/step - loss: 0.3743 - accuracy: 0.8790 - micro_f1_score: 0.8792 - val_loss: 1.4364 - val_accuracy: 0.6737 - val_micro_f1_score: 0.6764 - lr: 1.0000e-04
# Epoch 11/100
# 133/133 [==============================] - 15s 109ms/step - loss: 0.3544 - accuracy: 0.8870 - micro_f1_score: 0.8867 - val_loss: 1.3837 - val_accuracy: 0.7119 - val_micro_f1_score: 0.7111 - lr: 1.0000e-04
# Epoch 12/100
# 133/133 [==============================] - 16s 115ms/step - loss: 0.3596 - accuracy: 0.8856 - micro_f1_score: 0.8852 - val_loss: 0.9186 - val_accuracy: 0.7415 - val_micro_f1_score: 0.7444 - lr: 1.0000e-04
# Epoch 13/100
# 133/133 [==============================] - 15s 108ms/step - loss: 0.2837 - accuracy: 0.9120 - micro_f1_score: 0.9120 - val_loss: 0.6602 - val_accuracy: 0.8559 - val_micro_f1_score: 0.8542 - lr: 1.0000e-04
# Epoch 14/100
# 133/133 [==============================] - 15s 112ms/step - loss: 0.2523 - accuracy: 0.9153 - micro_f1_score: 0.9151 - val_loss: 1.0838 - val_accuracy: 0.7924 - val_micro_f1_score: 0.7889 - lr: 1.0000e-04
# Epoch 15/100
# 133/133 [==============================] - 15s 109ms/step - loss: 0.2914 - accuracy: 0.9124 - micro_f1_score: 0.9126 - val_loss: 0.8473 - val_accuracy: 0.8305 - val_micro_f1_score: 0.8292 - lr: 1.0000e-04
# Epoch 16/100
# 133/133 [==============================] - 16s 114ms/step - loss: 0.2534 - accuracy: 0.9298 - micro_f1_score: 0.9298 - val_loss: 0.6382 - val_accuracy: 0.8432 - val_micro_f1_score: 0.8431 - lr: 1.0000e-04
# Epoch 17/100
# 133/133 [==============================] - 15s 106ms/step - loss: 0.2164 - accuracy: 0.9346 - micro_f1_score: 0.9345 - val_loss: 1.0667 - val_accuracy: 0.7839 - val_micro_f1_score: 0.7861 - lr: 1.0000e-04
# Epoch 18/100
# 133/133 [==============================] - 15s 111ms/step - loss: 0.1877 - accuracy: 0.9360 - micro_f1_score: 0.9358 - val_loss: 0.8546 - val_accuracy: 0.8347 - val_micro_f1_score: 0.8361 - lr: 1.0000e-04
# Epoch 19/100
# 133/133 [==============================] - 15s 106ms/step - loss: 0.2207 - accuracy: 0.9369 - micro_f1_score: 0.9370 - val_loss: 0.9556 - val_accuracy: 0.8263 - val_micro_f1_score: 0.8278 - lr: 1.0000e-04
# Epoch 20/100
# 133/133 [==============================] - 15s 112ms/step - loss: 0.1733 - accuracy: 0.9487 - micro_f1_score: 0.9488 - val_loss: 0.6535 - val_accuracy: 0.8347 - val_micro_f1_score: 0.8333 - lr: 1.0000e-04
# Epoch 21/100
# 133/133 [==============================] - 15s 106ms/step - loss: 0.1628 - accuracy: 0.9562 - micro_f1_score: 0.9560 - val_loss: 0.6831 - val_accuracy: 0.8559 - val_micro_f1_score: 0.8583 - lr: 1.0000e-04
# Epoch 22/100
# 133/133 [==============================] - 15s 108ms/step - loss: 0.1452 - accuracy: 0.9590 - micro_f1_score: 0.9591 - val_loss: 1.2196 - val_accuracy: 0.7458 - val_micro_f1_score: 0.7444 - lr: 1.0000e-04
# Epoch 23/100
# 133/133 [==============================] - 15s 106ms/step - loss: 0.1657 - accuracy: 0.9510 - micro_f1_score: 0.9508 - val_loss: 1.1843 - val_accuracy: 0.7924 - val_micro_f1_score: 0.7958 - lr: 1.0000e-04
# Epoch 24/100
# 133/133 [==============================] - 15s 107ms/step - loss: 0
# 133/133 [==============================] - 15s 106ms/step - loss: 0.0396 - accuracy: 0.9981 - micro_f1_score: 0.9981 - val_loss: 0.5589 - val_accuracy: 0.8983 - val_micro_f1_score: 0.9000 - lr: 1.0000e-06

# %%
plot_model_history(history_mobilenet)

# %% [markdown]
# ## Ensemble

# %%
def create_ensemble(models):
    input_layer = Input(shape=(224, 224, 3))  # input layer

    # get output for each input model
    outputs = [model(input_layer) for model in models] 

    # take average of the outputs
    x = Average()(outputs) 
    
    # final layer
    output = Dense(6, activation="softmax")(x)

    # create average ensembled model
    avg_model = Model(input_layer, output)
    
    avg_model.compile(optimizer=SGD(learning_rate=1e-2), loss="categorical_crossentropy", metrics=["accuracy", micro_f1_score])
    
    return avg_model

# %%
models = [model_densenet, model_efficient]
ensemble = create_ensemble(models)
ensemble.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  DenseNet201 (Functional)       (None, 6)            18452998    ['input_13[0][0]']
#
#  EfficientNet (Functional)      (None, 6)            53237882    ['input_13[0][0]']
#
#  average_2 (Average)            (None, 6)            0           ['DenseNet201[2][0]',
#                                                                   'EfficientNet[2][0]']
#
#  dense_12 (Dense)               (None, 6)            42          ['average_2[0][0]']
#
# ==================================================================================================
# Total params: 71,690,922
# Trainable params: 71,163,434
# Non-trainable params: 527,488
# __________________________________________________________________________________________________

# %%
#history_ensemble = ensemble.fit(train_ds, validation_data = val_ds, epochs=100, callbacks=[reduce_lr, early_stopping])

# %% [markdown]
# <a id='test-data'></a>
# # Test data

# %%
# remove loaded images from the output folder
shutil.rmtree(preprocessed_train_images_dir)
shutil.rmtree(preprocessed_val_images_dir)

# %% [markdown]
# <a id='test-preprocessing'></a>
# ## Preprocessing

# %%
image_filenames = os.listdir(TEST_IMAGES_SRC_PATH)
len(image_filenames)
# Out:
# 756

# %%
resizer = Resizing(IMG_SIZE, IMG_SIZE, interpolation='bilinear')

# %%
def preprocess_test_img(img_path):
    #img = rembg(img_path) # remove background
    #img = img.convert("RGB") # remove alpha
    img = load_img(img_path) # image loading
    img_arr = img_to_array(img) # convert image to numpy array
    img_arr = resizer(img_arr) # resize
    return img_arr

# %%
test_data_preprocessed = [preprocess_test_img(TEST_IMAGES_SRC_PATH + img) for img in image_filenames]

# %%
X_test = np.stack(test_data_preprocessed, axis=0)
X_test.shape
# Out:
# (756, 224, 224, 3)

# %% [markdown]
# <a id='inference'></a>
# ## Inference

# %%
predictions = ensemble.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# 24/24 [==============================] - 13s 197ms/step

# %%
df_predictions = pd.DataFrame({
    'image_id': image_filenames,
    'class_6': predicted_classes
})

# %%
df_predictions.head()
# Out:
#                                image_id  class_6
# 0  07620090bd3581a0c7c344750f18621b.jpg        1
# 1  277bdc60f20a49d73525ab24a6e2128a.jpg        5
# 2  798d7ed914181f0f61f1e84de6ae7bab.jpg        0
# 3  81def953c8ba1b3e084582f11972e135.jpg        1
# 4  772c257c9a37357eec811b923109fcb4.jpg        5

# %%
df_predictions['class_6'].value_counts()
# Out:
# 2    256
# 1    197
# 0    171
# 5     75
# 3     57
# Name: class_6, dtype: int64

# %%
df_predictions.to_csv('submission.csv', index=False)

# %%
model.save('last.h5')
